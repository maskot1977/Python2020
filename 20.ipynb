# %% [markdown]
# <a href="https://colab.research.google.com/github/maskot1977/Python2020/blob/main/20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !date
# Out:
# Mon Oct  5 08:13:28 UTC 2020

# %%
import urllib.request

url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/location.txt'

urllib.request.urlretrieve(url, 'location.txt')
# Out:
# ('location.txt', <http.client.HTTPMessage at 0x7fc332e4cfd0>)

# %%
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('location.txt')):
    if i == 0:
        continue
    c = line.split(",")
    col1.append(c[0])
    col2.append(float(c[1]))
    col3.append(float(c[2]))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(col3, col2)
plt.title("Prefectural capitals in Japan")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid() 
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(col3, col2, alpha=0.5)
plt.title("Prefectural capitals in Japan")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
for city, x, y in zip(col1, col3, col2):
    plt.text(x, y, city, alpha=0.5, size=12)
plt.show()

# %%
# !date
# Out:
# Mon Oct  5 08:13:30 UTC 2020
