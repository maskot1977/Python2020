# %% [markdown]
# <a href="https://colab.research.google.com/github/maskot1977/Python2020/blob/1104/69.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !date
# Out:
# Thu Nov 19 04:48:45 UTC 2020

# %%
import urllib.request
import pandas as pd

# ニューヨークの大気状態観測値データ
url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/airquality.txt' 
urllib.request.urlretrieve(url, 'airquality.txt')

df = pd.read_csv('airquality.txt', sep='\t', index_col=0)

# %%
import matplotlib.pyplot as plt
from pandas import plotting 

plotting.scatter_matrix(df[df.columns[0:4]], figsize=(8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc2811e93c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc2811c2668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc2811778d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc28112ab38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc281162438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc2811146a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc2810c8908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc28107bb38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc28107bba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc280ff1048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc2810232e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc280fd5550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc280f887b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc280f3da20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc280eeec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc280ea5ef0>]],
#       dtype=object)

# %%
# !date
# Out:
# Thu Nov 19 04:49:09 UTC 2020
